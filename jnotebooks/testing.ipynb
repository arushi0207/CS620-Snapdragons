# %%
import numpy as np
import os
os.chdir("/Users/felixzhu/CS/CS620/CS620-Snapdragons/jnotebooks")
os.getcwd()
emb = np.load("/Users/felixzhu/CS/CS620/CS620-Snapdragons/context_generator/output/embeddings.npy")
emb
# Out:
# array([[-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815],
#        [-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815],
#        [-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815],
#        ...,
#        [-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815],
#        [-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815],
#        [-0.7316099 ,  1.1465554 ,  7.1348968 , ..., -0.4967325 ,
#          2.9711318 , -0.18065815]], shape=(572, 1536), dtype=float32)
